# %% [markdown]
# <h1>Two hidden layer Neural Network in Tensorflow</h1>

# %%
import numpy as np
import tensorflow as tf

import matplotlib.pyplot as plt

# %%
from util import get_normalized_data, y2indicator

# %%
def error_rate(p,r):
    return np.mean(p != r)

# %%
def main():
    # Get the data and variables
    X,Y =get_normalized_data()
    max_iter = 30
    print_period = 10
    lr = 0.00004
    reg = 0.01
    
    Xtrain = X[:-1000,]
    Ytrain = Y[:-1000]
    Xtest = X[-1000:]
    Ytest = Y[-1000:]
    
    Ytrain_ind = y2indicator(Ytrain)
    Ytest_ind = y2indicator(Ytest)
    
    N,D = Xtrain.shape
    batch_sz = 500
    n_batches = N/batch_sz
    
    # Creating initial values for weights and bias variables
    M1 = 300
    M2 = 100
    K = 10
    W1_init = np.random.randn(D,M1) / 28
    b1_init = np.zeros(M1)
    W2_init = np.random.randn(M1,M2)/np.sqrt(M1)
    b2_init = np.zeros(M2)
    W3_init = np.random.randn(M2,K)/np.sqrt(M2)
    b3_init = np.zeros(K)
    
    # Define Tensorflow variables and expressions
    # Tensorflow variables are like Theano shared variables but,
    # Theano variables are like Tensorflow placeholders.
    
    X = tf.placeholder(tf.float32, shape=[None, D], name='X')
    T = tf.placeholder(tf.float32, shape=[None, K], name="T")
    W1 = tf.Variable(W1_init.astype(np.float32))
    b1 = tf.Variable(b1_init.astype(np.float32))
    W2 = tf.Variable(W2_init.astype(np.float32))
    b2 = tf.Variable(b2_init.astype(np.float32))
    W3 = tf.Variable(W3_init.astype(np.float32))
    b3 = tf.Variable(b3_init.astype(np.float32))
    
    # Using Tensorflow functions to define the model
    Z1 = tf.nn.relu(tf.matmul(X,W1) + b1)
    Z2 = tf.nn.relu(tf.matmul(Z1,W2) + b2)
    Yish = tf.matmul(Z2,W3) + b3 # Softmax is included in the cost calculation for some reason.
    
    # softmax_cross_entropy_with_logits takes in the "logits"
    # if you wanted to know the actual output of the neural net,
    # you could pass "Yish" into tf.nn.softmax(logits)
    cost = tf.reduce_sum(tf.nn.softmax_cross_entropy_with_logits(logits=Yish, labels=T))
    
    # One difference between Theano and TensorFlow is that you don't write the updates
    # yourself in TensorFlow. You choose an optimizer that implements the algorithm you want.
    train_op = tf.train.RMSPropOptimizer(lr, decay=0.99, momentum=0.9).minimize(cost)

    predict_op = tf.argmax(Yish,1)
    LL = [] # Loglikelihood
    init = tf.initialize_all_variables()
    with tf.Session() as session:
        session.run(init)
        
        for i in xrange(max_iter):
            for j in xrange(n_batches):
                Xbatch = Xtrain[j*batch_sz:(j+1)*batch_sz,]
                Ybatch = Ytrain_ind[j*batch_sz:(j+1)*batch_sz,]
    
                session.run(train_op, feed_dict={X: Xbatch, T: Ybatch})
                if j % print_period ==0:
                    test_cost = session.run(cost, feed_dict={X:Xtest, T:Ytest_ind})
                    prediction = session.run(predict_op, feed_dict={X: Xtest})
                    err = error_rate(prediction, Ytest)
                    print "Cost / err at iteration i=%d, j=%d: %.3f / %.3f" % (i,j,test_cost,err)
                    LL.append(test_cost)
                    
    plt.plot(LL)
    plt.show()

# %%
if __name__ == "__main__":
    main()
# Out:
# Reading in and transforming data...
# Cost / err at iteration i=0, j=0: 2420.646 / 0.903
# Cost / err at iteration i=0, j=10: 1625.347 / 0.354
# Cost / err at iteration i=0, j=20: 906.337 / 0.237
# Cost / err at iteration i=0, j=30: 571.126 / 0.151
# Cost / err at iteration i=0, j=40: 448.959 / 0.130
# Cost / err at iteration i=0, j=50: 374.560 / 0.120
# Cost / err at iteration i=0, j=60: 331.695 / 0.102
# Cost / err at iteration i=0, j=70: 301.749 / 0.091
# Cost / err at iteration i=0, j=80: 272.046 / 0.081
# Cost / err at iteration i=1, j=0: 266.334 / 0.080
# Cost / err at iteration i=1, j=10: 246.108 / 0.076
# Cost / err at iteration i=1, j=20: 235.736 / 0.075
# Cost / err at iteration i=1, j=30: 224.269 / 0.070
# Cost / err at iteration i=1, j=40: 214.932 / 0.069
# Cost / err at iteration i=1, j=50: 204.454 / 0.063
# Cost / err at iteration i=1, j=60: 202.405 / 0.065
# Cost / err at iteration i=1, j=70: 189.893 / 0.061
# Cost / err at iteration i=1, j=80: 181.883 / 0.059
# Cost / err at iteration i=2, j=0: 179.583 / 0.055
# Cost / err at iteration i=2, j=10: 171.447 / 0.055
# Cost / err at iteration i=2, j=20: 169.624 / 0.054
# Cost / err at iteration i=2, j=30: 165.508 / 0.053
# Cost / err at iteration i=2, j=40: 159.352 / 0.053
# Cost / err at iteration i=2, j=50: 155.785 / 0.053
# Cost / err at iteration i=2, j=60: 157.407 / 0.051
# Cost / err at iteration i=2, j=70: 148.025 / 0.049
# Cost / err at iteration i=2, j=80: 142.449 / 0.046
# Cost / err at iteration i=3, j=0: 140.927 / 0.046
# Cost / err at iteration i=3, j=10: 135.897 / 0.046
# Cost / err at iteration i=3, j=20: 135.778 / 0.044
# Cost / err at iteration i=3, j=30: 133.781 / 0.044
# Cost / err at iteration i=3, j=40: 128.915 / 0.045
# Cost / err at iteration i=3, j=50: 127.209 / 0.048
# Cost / err at iteration i=3, j=60: 131.106 / 0.046
# Cost / err at iteration i=3, j=70: 124.127 / 0.035
# Cost / err at iteration i=3, j=80: 119.892 / 0.036
# Cost / err at iteration i=4, j=0: 119.010 / 0.036
# Cost / err at iteration i=4, j=10: 114.198 / 0.042
# Cost / err at iteration i=4, j=20: 113.924 / 0.038
# Cost / err at iteration i=4, j=30: 113.342 / 0.035
# Cost / err at iteration i=4, j=40: 108.805 / 0.034
# Cost / err at iteration i=4, j=50: 107.954 / 0.032
# Cost / err at iteration i=4, j=60: 112.970 / 0.042
# Cost / err at iteration i=4, j=70: 107.631 / 0.035
# Cost / err at iteration i=4, j=80: 103.394 / 0.035
# Cost / err at iteration i=5, j=0: 102.852 / 0.035
# Cost / err at iteration i=5, j=10: 98.223 / 0.033
# Cost / err at iteration i=5, j=20: 97.714 / 0.032
# Cost / err at iteration i=5, j=30: 98.556 / 0.033
# Cost / err at iteration i=5, j=40: 95.398 / 0.032
# Cost / err at iteration i=5, j=50: 95.002 / 0.032
# Cost / err at iteration i=5, j=60: 100.340 / 0.035
# Cost / err at iteration i=5, j=70: 94.814 / 0.031
# Cost / err at iteration i=5, j=80: 92.322 / 0.030
# Cost / err at iteration i=6, j=0: 91.938 / 0.030
# Cost / err at iteration i=6, j=10: 87.735 / 0.030
# Cost / err at iteration i=6, j=20: 87.725 / 0.031
# Cost / err at iteration i=6, j=30: 88.907 / 0.035
# Cost / err at iteration i=6, j=40: 85.267 / 0.031
# Cost / err at iteration i=6, j=50: 85.855 / 0.034
# Cost / err at iteration i=6, j=60: 91.621 / 0.033
# Cost / err at iteration i=6, j=70: 86.639 / 0.027
# Cost / err at iteration i=6, j=80: 83.537 / 0.028
# Cost / err at iteration i=7, j=0: 83.054 / 0.028
# Cost / err at iteration i=7, j=10: 80.304 / 0.027
# Cost / err at iteration i=7, j=20: 79.917 / 0.030
# Cost / err at iteration i=7, j=30: 81.237 / 0.032
# Cost / err at iteration i=7, j=40: 78.095 / 0.029
# Cost / err at iteration i=7, j=50: 79.524 / 0.033
# Cost / err at iteration i=7, j=60: 85.961 / 0.031
# Cost / err at iteration i=7, j=70: 81.797 / 0.029
# Cost / err at iteration i=7, j=80: 78.223 / 0.026
# Cost / err at iteration i=8, j=0: 77.685 / 0.024
# Cost / err at iteration i=8, j=10: 76.621 / 0.030
# Cost / err at iteration i=8, j=20: 75.372 / 0.024
# Cost / err at iteration i=8, j=30: 76.184 / 0.031
# Cost / err at iteration i=8, j=40: 73.537 / 0.030
# Cost / err at iteration i=8, j=50: 75.185 / 0.031
# Cost / err at iteration i=8, j=60: 82.680 / 0.033
# Cost / err at iteration i=8, j=70: 78.607 / 0.025
# Cost / err at iteration i=8, j=80: 74.889 / 0.025
# Cost / err at iteration i=9, j=0: 74.178 / 0.024
# Cost / err at iteration i=9, j=10: 74.106 / 0.028
# Cost / err at iteration i=9, j=20: 72.487 / 0.023
# Cost / err at iteration i=9, j=30: 71.646 / 0.028
# Cost / err at iteration i=9, j=40: 70.474 / 0.027
# Cost / err at iteration i=9, j=50: 72.249 / 0.027
# Cost / err at iteration i=9, j=60: 79.823 / 0.032
# Cost / err at iteration i=9, j=70: 76.478 / 0.025
# Cost / err at iteration i=9, j=80: 72.954 / 0.023
# Cost / err at iteration i=10, j=0: 72.252 / 0.023
# Cost / err at iteration i=10, j=10: 72.772 / 0.024
# Cost / err at iteration i=10, j=20: 70.974 / 0.023
# Cost / err at iteration i=10, j=30: 69.242 / 0.025
# Cost / err at iteration i=10, j=40: 68.450 / 0.025
# Cost / err at iteration i=10, j=50: 70.408 / 0.026
# Cost / err at iteration i=10, j=60: 78.431 / 0.030
# Cost / err at iteration i=10, j=70: 75.914 / 0.024
# Cost / err at iteration i=10, j=80: 72.623 / 0.022
# Cost / err at iteration i=11, j=0: 71.726 / 0.021
# Cost / err at iteration i=11, j=10: 71.920 / 0.024
# Cost / err at iteration i=11, j=20: 70.099 / 0.023
# Cost / err at iteration i=11, j=30: 67.899 / 0.026
# Cost / err at iteration i=11, j=40: 67.003 / 0.025
# Cost / err at iteration i=11, j=50: 69.529 / 0.023
# Cost / err at iteration i=11, j=60: 76.219 / 0.031
# Cost / err at iteration i=11, j=70: 75.988 / 0.025
# Cost / err at iteration i=11, j=80: 73.762 / 0.023
# Cost / err at iteration i=12, j=0: 72.793 / 0.023
# Cost / err at iteration i=12, j=10: 71.473 / 0.022
# Cost / err at iteration i=12, j=20: 70.084 / 0.024
# Cost / err at iteration i=12, j=30: 67.383 / 0.027
# Cost / err at iteration i=12, j=40: 66.671 / 0.024
# Cost / err at iteration i=12, j=50: 68.314 / 0.024
# Cost / err at iteration i=12, j=60: 74.603 / 0.029
# Cost / err at iteration i=12, j=70: 75.316 / 0.025
# Cost / err at iteration i=12, j=80: 74.775 / 0.024
# Cost / err at iteration i=13, j=0: 73.976 / 0.023
# Cost / err at iteration i=13, j=10: 71.778 / 0.022
# Cost / err at iteration i=13, j=20: 70.555 / 0.024
# Cost / err at iteration i=13, j=30: 67.426 / 0.025
# Cost / err at iteration i=13, j=40: 66.694 / 0.024
# Cost / err at iteration i=13, j=50: 68.898 / 0.024
# Cost / err at iteration i=13, j=60: 73.853 / 0.027
# Cost / err at iteration i=13, j=70: 75.154 / 0.024
# Cost / err at iteration i=13, j=80: 75.385 / 0.024
# Cost / err at iteration i=14, j=0: 75.272 / 0.027
# Cost / err at iteration i=14, j=10: 72.487 / 0.023
# Cost / err at iteration i=14, j=20: 71.141 / 0.022
# Cost / err at iteration i=14, j=30: 68.497 / 0.026
# Cost / err at iteration i=14, j=40: 68.701 / 0.023
# Cost / err at iteration i=14, j=50: 68.965 / 0.023
# Cost / err at iteration i=14, j=60: 74.635 / 0.027
# Cost / err at iteration i=14, j=70: 75.264 / 0.025
# Cost / err at iteration i=14, j=80: 77.140 / 0.024
# Cost / err at iteration i=15, j=0: 77.295 / 0.026
# Cost / err at iteration i=15, j=10: 74.998 / 0.024
# Cost / err at iteration i=15, j=20: 73.373 / 0.022
# Cost / err at iteration i=15, j=30: 70.621 / 0.027
# Cost / err at iteration i=15, j=40: 68.524 / 0.024
# Cost / err at iteration i=15, j=50: 69.359 / 0.024
# Cost / err at iteration i=15, j=60: 73.152 / 0.024
# Cost / err at iteration i=15, j=70: 74.529 / 0.024
# Cost / err at iteration i=15, j=80: 76.312 / 0.024
# Cost / err at iteration i=16, j=0: 77.043 / 0.025
# Cost / err at iteration i=16, j=10: 76.936 / 0.025
# Cost / err at iteration i=16, j=20: 74.773 / 0.022
# Cost / err at iteration i=16, j=30: 72.173 / 0.026
# Cost / err at iteration i=16, j=40: 71.490 / 0.026
# Cost / err at iteration i=16, j=50: 68.466 / 0.022
# Cost / err at iteration i=16, j=60: 74.928 / 0.025
# Cost / err at iteration i=16, j=70: 75.789 / 0.022
# Cost / err at iteration i=16, j=80: 78.080 / 0.024
# Cost / err at iteration i=17, j=0: 78.133 / 0.024
# Cost / err at iteration i=17, j=10: 77.850 / 0.024
# Cost / err at iteration i=17, j=20: 77.410 / 0.023
# Cost / err at iteration i=17, j=30: 74.135 / 0.027
# Cost / err at iteration i=17, j=40: 73.039 / 0.027
# Cost / err at iteration i=17, j=50: 68.619 / 0.020
# Cost / err at iteration i=17, j=60: 76.805 / 0.026
# Cost / err at iteration i=17, j=70: 77.144 / 0.025
# Cost / err at iteration i=17, j=80: 78.891 / 0.021
# Cost / err at iteration i=18, j=0: 79.998 / 0.022
# Cost / err at iteration i=18, j=10: 81.139 / 0.024
# Cost / err at iteration i=18, j=20: 78.432 / 0.025
# Cost / err at iteration i=18, j=30: 75.798 / 0.028
# Cost / err at iteration i=18, j=40: 78.591 / 0.028
# Cost / err at iteration i=18, j=50: 72.227 / 0.018
# Cost / err at iteration i=18, j=60: 79.717 / 0.026
# Cost / err at iteration i=18, j=70: 79.228 / 0.023
# Cost / err at iteration i=18, j=80: 78.786 / 0.020
# Cost / err at iteration i=19, j=0: 80.819 / 0.020
# Cost / err at iteration i=19, j=10: 86.583 / 0.026
# Cost / err at iteration i=19, j=20: 78.087 / 0.025
# Cost / err at iteration i=19, j=30: 75.144 / 0.026
# Cost / err at iteration i=19, j=40: 83.040 / 0.027
# Cost / err at iteration i=19, j=50: 76.959 / 0.020
# Cost / err at iteration i=19, j=60: 88.210 / 0.025
# Cost / err at iteration i=19, j=70: 82.442 / 0.022
# Cost / err at iteration i=19, j=80: 82.702 / 0.022
# Cost / err at iteration i=20, j=0: 82.746 / 0.019
# Cost / err at iteration i=20, j=10: 86.042 / 0.023
# Cost / err at iteration i=20, j=20: 82.130 / 0.024
# Cost / err at iteration i=20, j=30: 74.772 / 0.023
# Cost / err at iteration i=20, j=40: 91.281 / 0.027
# Cost / err at iteration i=20, j=50: 86.513 / 0.027
# Cost / err at iteration i=20, j=60: 102.385 / 0.028
# Cost / err at iteration i=20, j=70: 94.320 / 0.025
# Cost / err at iteration i=20, j=80: 101.876 / 0.027
# Cost / err at iteration i=21, j=0: 99.450 / 0.024
# Cost / err at iteration i=21, j=10: 89.019 / 0.025
# Cost / err at iteration i=21, j=20: 88.820 / 0.025
# Cost / err at iteration i=21, j=30: 80.681 / 0.025
# Cost / err at iteration i=21, j=40: 97.249 / 0.026
# Cost / err at iteration i=21, j=50: 96.429 / 0.027
# Cost / err at iteration i=21, j=60: 97.236 / 0.026
# Cost / err at iteration i=21, j=70: 92.137 / 0.025
# Cost / err at iteration i=21, j=80: 100.120 / 0.029
# Cost / err at iteration i=22, j=0: 99.427 / 0.028
# Cost / err at iteration i=22, j=10: 114.479 / 0.028
# Cost / err at iteration i=22, j=20: 103.614 / 0.028
# Cost / err at iteration i=22, j=30: 89.069 / 0.025
# Cost / err at iteration i=22, j=40: 93.724 / 0.028
# Cost / err at iteration i=22, j=50: 108.087 / 0.030
# Cost / err at iteration i=22, j=60: 104.348 / 0.028
# Cost / err at iteration i=22, j=70: 95.797 / 0.022
# Cost / err at iteration i=22, j=80: 100.695 / 0.024
# Cost / err at iteration i=23, j=0: 102.442 / 0.024
# Cost / err at iteration i=23, j=10: 102.247 / 0.024
# Cost / err at iteration i=23, j=20: 98.954 / 0.026
# Cost / err at iteration i=23, j=30: 86.471 / 0.024
# Cost / err at iteration i=23, j=40: 82.753 / 0.026
# Cost / err at iteration i=23, j=50: 88.870 / 0.028
# Cost / err at iteration i=23, j=60: 92.686 / 0.024
# Cost / err at iteration i=23, j=70: 89.740 / 0.024
# Cost / err at iteration i=23, j=80: 89.019 / 0.026
# Cost / err at iteration i=24, j=0: 90.940 / 0.026
# Cost / err at iteration i=24, j=10: 94.311 / 0.025
# Cost / err at iteration i=24, j=20: 99.252 / 0.026
# Cost / err at iteration i=24, j=30: 91.142 / 0.029
# Cost / err at iteration i=24, j=40: 89.018 / 0.027
# Cost / err at iteration i=24, j=50: 87.881 / 0.026
# Cost / err at iteration i=24, j=60: 88.855 / 0.025
# Cost / err at iteration i=24, j=70: 86.346 / 0.023
# Cost / err at iteration i=24, j=80: 85.628 / 0.024
# Cost / err at iteration i=25, j=0: 85.969 / 0.024
# Cost / err at iteration i=25, j=10: 88.878 / 0.022
# Cost / err at iteration i=25, j=20: 93.386 / 0.023
# Cost / err at iteration i=25, j=30: 91.454 / 0.025
# Cost / err at iteration i=25, j=40: 85.124 / 0.025
# Cost / err at iteration i=25, j=50: 84.766 / 0.027
# Cost / err at iteration i=25, j=60: 89.321 / 0.025
# Cost / err at iteration i=25, j=70: 87.975 / 0.026
# Cost / err at iteration i=25, j=80: 84.141 / 0.024
# Cost / err at iteration i=26, j=0: 84.046 / 0.023
# Cost / err at iteration i=26, j=10: 88.636 / 0.023
# Cost / err at iteration i=26, j=20: 92.377 / 0.023
# Cost / err at iteration i=26, j=30: 87.478 / 0.023
# Cost / err at iteration i=26, j=40: 84.401 / 0.026
# Cost / err at iteration i=26, j=50: 85.440 / 0.025
# Cost / err at iteration i=26, j=60: 87.606 / 0.025
# Cost / err at iteration i=26, j=70: 87.033 / 0.025
# Cost / err at iteration i=26, j=80: 84.259 / 0.025
# Cost / err at iteration i=27, j=0: 84.786 / 0.024
# Cost / err at iteration i=27, j=10: 87.930 / 0.024
# Cost / err at iteration i=27, j=20: 90.549 / 0.022
# Cost / err at iteration i=27, j=30: 88.235 / 0.023
# Cost / err at iteration i=27, j=40: 83.480 / 0.026
# Cost / err at iteration i=27, j=50: 85.034 / 0.026
# Cost / err at iteration i=27, j=60: 88.785 / 0.025
# Cost / err at iteration i=27, j=70: 87.057 / 0.024
# Cost / err at iteration i=27, j=80: 84.291 / 0.023
# Cost / err at iteration i=28, j=0: 84.077 / 0.023
# Cost / err at iteration i=28, j=10: 86.608 / 0.023
# Cost / err at iteration i=28, j=20: 91.714 / 0.022
# Cost / err at iteration i=28, j=30: 88.209 / 0.024
# Cost / err at iteration i=28, j=40: 82.617 / 0.024
# Cost / err at iteration i=28, j=50: 83.780 / 0.024
# Cost / err at iteration i=28, j=60: 87.491 / 0.023
# Cost / err at iteration i=28, j=70: 86.821 / 0.023
# Cost / err at iteration i=28, j=80: 84.492 / 0.023
# Cost / err at iteration i=29, j=0: 84.365 / 0.023
# Cost / err at iteration i=29, j=10: 87.618 / 0.023
# Cost / err at iteration i=29, j=20: 91.352 / 0.022
# Cost / err at iteration i=29, j=30: 89.026 / 0.024
# Cost / err at iteration i=29, j=40: 83.930 / 0.024
# Cost / err at iteration i=29, j=50: 84.836 / 0.024
# Cost / err at iteration i=29, j=60: 88.143 / 0.022
# Cost / err at iteration i=29, j=70: 87.462 / 0.022
# Cost / err at iteration i=29, j=80: 85.607 / 0.023

# %%
# It can be seen that the Log-likelihood increase after a while. 
# Which means our model starts overfitting.
